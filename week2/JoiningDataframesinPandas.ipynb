# %%
import os
import pandas as pd

wd = r'C:\Users\Ider.E\Desktop\PythonCourse\Lecture2\repo2\week2'
wd = wd.replace('\\', '/') # wd.replace(os.sep, '/')

os.chdir(wd) #set working directory to wd

# %%
#import data
df_ind = pd.read_excel('data_more.xlsx', sheet_name = 'loan_ind',
                      usecols='D:I,L', skiprows=6, header=0)
df_ind
# Out:
#    id  clientId firstName lastName loanStatus  loanAmount  issueDate
# 0   1    115380     Suren    Itgel       norm    14000000       2015
# 1   2    197540    Chimeg   Baldan       norm    12000000       2016
# 2   3    127843     Gerel     Tsog        bad    14000000       2017
# 3   4    174455   Kherlen     Sukh       ovrd    10000000       2015
# 4   5    104349    Badral  Damchaa       doub    18000000       2019
# 5   6    156346    Dondog    Uuree        bad    16000000       2020
# 6   7    162767      Dash   Byamba       ovrd    13000000       2021
# 7   8    139840       Bat    Bayar       norm    17000000       2018
# 8   9    159625     Saran  Tuvshin        bad    10000000       2019
# 9  10    185473     Naran  Saikhan       subs    13000000       2018

# %%
df_corp = pd.read_excel('data_more.xlsx', sheet_name = 'loan_corp',
                     usecols='C:F', skiprows=3, header=0)
df_corp.head()
# Out:
#    Харилцагчийн дугаар  Зээлийн хэмжээ (төгрөг)  Олгосон огноо  \
# 0               115380                 62000000           2015
# 1               127843                 74000000           2017
# 2               104349                 72000000           2019
# 3               156346                 79000000           2020
# 4               162767                 59000000           2021
#
#      Зээлийн статус
# 0               муу
# 1         эргэлзээт
# 2  хугацаа хэтэрсэн
# 3        хэвийн бус
# 4            Хэвийн

# %%
df_corp.columns
# Out:
# Index(['Харилцагчийн дугаар', 'Зээлийн хэмжээ (төгрөг)', 'Олгосон огноо',
#        'Зээлийн статус'],
#       dtype='object')

# %%
df_corp.rename(columns ={'Харилцагчийн дугаар': 'clientId'}, inplace=True)
df_corp
# Out:
#    clientId  loanAmaount  issueDate        loanStatus
# 0    115380     62000000       2015               муу
# 1    127843     74000000       2017         эргэлзээт
# 2    104349     72000000       2019  хугацаа хэтэрсэн
# 3    156346     79000000       2020        хэвийн бус
# 4    162767     59000000       2021            Хэвийн
# 5    159625     64000000       2019       эргэлзээтэй
# 6    185473     68000000       2018               муу
# 7    159789     74000000       2017            хэвийн
# 8    185121     63000000       2019               муу

# %%
df_corp.rename(columns = {'Зээлийн хэмжээ (төгрөг)': 'loanAmount', 'Олгосон огноо': 'issueDate', 'Зээлийн статус': 'loanStatus'}, inplace=True)
df_corp

df_corp.rename(columns = {'loanAmaount': 'loanAmount'}, inplace = True)

# %%
df_corp.columns = ['clientId', 'loanAmount', 'issueDate','loanStatus,']
df_corp
# Out:
#    clientId  loanAmount  issueDate      loanStatus,
# 0    115380    62000000       2015               муу
# 1    127843    74000000       2017         эргэлзээт
# 2    104349    72000000       2019  хугацаа хэтэрсэн
# 3    156346    79000000       2020        хэвийн бус
# 4    162767    59000000       2021            Хэвийн
# 5    159625    64000000       2019       эргэлзээтэй
# 6    185473    68000000       2018               муу
# 7    159789    74000000       2017            хэвийн
# 8    185121    63000000       2019               муу

# %%
df_ind
# Out:
#    id  clientId firstName lastName loanStatus  loanAmount  issueDate
# 0   1    115380     Suren    Itgel       norm    14000000       2015
# 1   2    197540    Chimeg   Baldan       norm    12000000       2016
# 2   3    127843     Gerel     Tsog        bad    14000000       2017
# 3   4    174455   Kherlen     Sukh       ovrd    10000000       2015
# 4   5    104349    Badral  Damchaa       doub    18000000       2019
# 5   6    156346    Dondog    Uuree        bad    16000000       2020
# 6   7    162767      Dash   Byamba       ovrd    13000000       2021
# 7   8    139840       Bat    Bayar       norm    17000000       2018
# 8   9    159625     Saran  Tuvshin        bad    10000000       2019
# 9  10    185473     Naran  Saikhan       subs    13000000       2018

# %%
df_ind['loanStatus'] #buh utgiig harah
df_ind['loanStatus'].unique() # buh utgaas neg negiig harah
# Out:
# array(['norm', 'bad', 'ovrd', 'doub', 'subs'], dtype=object)

# %%
df_corp
# Out:
#    clientId  loanAmount  issueDate      loanStatus,
# 0    115380    62000000       2015               муу
# 1    127843    74000000       2017         эргэлзээт
# 2    104349    72000000       2019  хугацаа хэтэрсэн
# 3    156346    79000000       2020        хэвийн бус
# 4    162767    59000000       2021            Хэвийн
# 5    159625    64000000       2019       эргэлзээтэй
# 6    185473    68000000       2018               муу
# 7    159789    74000000       2017            хэвийн
# 8    185121    63000000       2019               муу

# %%
df_corp.rename(columns = {'loanStatus, ': 'loanStatus'}, inplace = True)
df_corp
# Out:
#    clientId  loanAmount  issueDate        loanStatus
# 0    115380    62000000       2015               муу
# 1    127843    74000000       2017         эргэлзээт
# 2    104349    72000000       2019  хугацаа хэтэрсэн
# 3    156346    79000000       2020        хэвийн бус
# 4    162767    59000000       2021            Хэвийн
# 5    159625    64000000       2019       эргэлзээтэй
# 6    185473    68000000       2018               муу
# 7    159789    74000000       2017            хэвийн
# 8    185121    63000000       2019               муу

# %%
df_corp['loanStatus'].unique()
# Out:
# array(['муу', 'эргэлзээт', 'хугацаа хэтэрсэн', 'хэвийн бус', 'Хэвийн',
#        'эргэлзээтэй', 'хэвийн'], dtype=object)

# %%
# Эргэлзээт гэдгийг эргэлзээтэйгээр солих

df_corp.loc[df_corp['loanStatus'] == 'эргэлзээт', 'loanStatus'] = 'Эргэлзээтэй'
df_corp['loanStatus'].unique()
# Out:
# array(['муу', 'Эргэлзээтэй', 'хугацаа хэтэрсэн', 'хэвийн бус', 'Хэвийн',
#        'эргэлзээтэй', 'хэвийн'], dtype=object)

# %%
df_corp.loc[df_corp['loanStatus'] == 'Эргэлзээтэй', 'loanStatus'] = 'эргэлзээтэй'
df_corp['loanStatus'].unique()
# Out:
# array(['муу', 'эргэлзээтэй', 'хугацаа хэтэрсэн', 'хэвийн бус', 'Хэвийн',
#        'хэвийн'], dtype=object)

# %%
df_corp.loc[df_corp['loanStatus'] == 'Хэвийн', 'loanStatus'] = 'хэвийн'
df_corp['loanStatus'].unique()
# Out:
# array(['муу', 'эргэлзээтэй', 'хугацаа хэтэрсэн', 'хэвийн бус', 'хэвийн'],
#       dtype=object)

# %%
status_map=dict(zip(['хэвийн', 'муу', 'хугацаа хэтэрсэн', 'эргэлзээтэй', 'хэвийн бус'], 
                    ['norm', 'bad', 'ovrd', 'doub', 'subs'])) #dictionary uusgev
status_map
# Out:
# {'хэвийн': 'norm',
#  'муу': 'bad',
#  'хугацаа хэтэрсэн': 'ovrd',
#  'эргэлзээтэй': 'doub',
#  'хэвийн бус': 'subs'}

# %%
df_corp['loanStatus'].map(status_map)
df_corp['loanStatus_en'] = df_corp['loanStatus'].map(status_map) #shine bagana uusgev
df_corp
# Out:
#    clientId  loanAmount  issueDate        loanStatus loanStatus_en
# 0    115380    62000000       2015               муу           bad
# 1    127843    74000000       2017       эргэлзээтэй          doub
# 2    104349    72000000       2019  хугацаа хэтэрсэн          ovrd
# 3    156346    79000000       2020        хэвийн бус          subs
# 4    162767    59000000       2021            хэвийн          norm
# 5    159625    64000000       2019       эргэлзээтэй          doub
# 6    185473    68000000       2018               муу           bad
# 7    159789    74000000       2017            хэвийн          norm
# 8    185121    63000000       2019               муу           bad

# %%
del df_corp['loanStatus'] # huuchin baganiig ustgav

# %%
# df_corp.drop('loanStatus', axis = 1, inplace = True) # baganiig uuruur ustgah arga
df_corp
# Out:
#    clientId  loanAmount  issueDate loanStatus_en
# 0    115380    62000000       2015           bad
# 1    127843    74000000       2017          doub
# 2    104349    72000000       2019          ovrd
# 3    156346    79000000       2020          subs
# 4    162767    59000000       2021          norm
# 5    159625    64000000       2019          doub
# 6    185473    68000000       2018           bad
# 7    159789    74000000       2017          norm
# 8    185121    63000000       2019           bad

# %%
df_corp.rename(columns={'loanStatus_en': 'loanStatus'}, inplace = True)
df_corp.columns
# Out:
# Index(['clientId', 'loanAmount', 'issueDate', 'loanStatus'], dtype='object')

# %%
# 2 dataga hoorond ni niiluuleh buyu concatenet
pd.concat([df_ind, df_corp], ignore_index=True)
# Out:
#       id  clientId firstName lastName loanStatus  loanAmount  issueDate
# 0    1.0    115380     Suren    Itgel       norm    14000000       2015
# 1    2.0    197540    Chimeg   Baldan       norm    12000000       2016
# 2    3.0    127843     Gerel     Tsog        bad    14000000       2017
# 3    4.0    174455   Kherlen     Sukh       ovrd    10000000       2015
# 4    5.0    104349    Badral  Damchaa       doub    18000000       2019
# 5    6.0    156346    Dondog    Uuree        bad    16000000       2020
# 6    7.0    162767      Dash   Byamba       ovrd    13000000       2021
# 7    8.0    139840       Bat    Bayar       norm    17000000       2018
# 8    9.0    159625     Saran  Tuvshin        bad    10000000       2019
# 9   10.0    185473     Naran  Saikhan       subs    13000000       2018
# 10   NaN    115380       NaN      NaN        bad    62000000       2015
# 11   NaN    127843       NaN      NaN       doub    74000000       2017
# ...

# %%
df_con = pd.concat([df_ind, df_corp], ignore_index=True)

# %%
df_con
# Out:
#       id  clientId firstName lastName loanStatus  loanAmount  issueDate
# 0    1.0    115380     Suren    Itgel       norm    14000000       2015
# 1    2.0    197540    Chimeg   Baldan       norm    12000000       2016
# 2    3.0    127843     Gerel     Tsog        bad    14000000       2017
# 3    4.0    174455   Kherlen     Sukh       ovrd    10000000       2015
# 4    5.0    104349    Badral  Damchaa       doub    18000000       2019
# 5    6.0    156346    Dondog    Uuree        bad    16000000       2020
# 6    7.0    162767      Dash   Byamba       ovrd    13000000       2021
# 7    8.0    139840       Bat    Bayar       norm    17000000       2018
# 8    9.0    159625     Saran  Tuvshin        bad    10000000       2019
# 9   10.0    185473     Naran  Saikhan       subs    13000000       2018
# 10   NaN    115380       NaN      NaN        bad    62000000       2015
# 11   NaN    127843       NaN      NaN       doub    74000000       2017
# ...

# %%
pd.concat([df_ind, df_corp], keys=['ind', 'corp']) #know the source
# Out:
#           id  clientId firstName lastName loanStatus  loanAmount  issueDate
# ind  0   1.0    115380     Suren    Itgel       norm    14000000       2015
#      1   2.0    197540    Chimeg   Baldan       norm    12000000       2016
#      2   3.0    127843     Gerel     Tsog        bad    14000000       2017
#      3   4.0    174455   Kherlen     Sukh       ovrd    10000000       2015
#      4   5.0    104349    Badral  Damchaa       doub    18000000       2019
#      5   6.0    156346    Dondog    Uuree        bad    16000000       2020
#      6   7.0    162767      Dash   Byamba       ovrd    13000000       2021
#      7   8.0    139840       Bat    Bayar       norm    17000000       2018
#      8   9.0    159625     Saran  Tuvshin        bad    10000000       2019
#      9  10.0    185473     Naran  Saikhan       subs    13000000       2018
# corp 0   NaN    115380       NaN      NaN        bad    62000000       2015
# ...

# %%
pd.concat([df_ind, df_corp], keys=['ind', 'corp']).reset_index() #mur bolgond ind corp gej oruulah
# Out:
#    level_0  level_1    id  clientId firstName lastName loanStatus  loanAmount  \
# 0      ind        0   1.0    115380     Suren    Itgel       norm    14000000
# 1      ind        1   2.0    197540    Chimeg   Baldan       norm    12000000
# 2      ind        2   3.0    127843     Gerel     Tsog        bad    14000000
# 3      ind        3   4.0    174455   Kherlen     Sukh       ovrd    10000000
# 4      ind        4   5.0    104349    Badral  Damchaa       doub    18000000
# 5      ind        5   6.0    156346    Dondog    Uuree        bad    16000000
# 6      ind        6   7.0    162767      Dash   Byamba       ovrd    13000000
# 7      ind        7   8.0    139840       Bat    Bayar       norm    17000000
# 8      ind        8   9.0    159625     Saran  Tuvshin        bad    10000000
# 9      ind        9  10.0    185473     Naran  Saikhan       subs    13000000
# 10    corp        0   NaN    115380       NaN      NaN        bad    62000000
# ...

# %%
# merge (join)
df_in = pd.merge(df_ind, df_corp, on='clientId') # clientId-r match hiisniig oloh (2+ zeeltei humuus)
df_in
# Out:
#    id  clientId firstName lastName loanStatus_x  loanAmount_x  issueDate_x  \
# 0   1    115380     Suren    Itgel         norm      14000000         2015
# 1   3    127843     Gerel     Tsog          bad      14000000         2017
# 2   5    104349    Badral  Damchaa         doub      18000000         2019
# 3   6    156346    Dondog    Uuree          bad      16000000         2020
# 4   7    162767      Dash   Byamba         ovrd      13000000         2021
# 5   9    159625     Saran  Tuvshin          bad      10000000         2019
# 6  10    185473     Naran  Saikhan         subs      13000000         2018
#
#    loanAmount_y  issueDate_y loanStatus_y
# 0      62000000         2015          bad
# 1      74000000         2017         doub
# 2      72000000         2019         ovrd
# 3      79000000         2020         subs
# 4      59000000         2021         norm
# 5      64000000         2019         doub
# 6      68000000         2018          bad

# %%
df_ou = pd.merge(df_ind, df_corp, on='clientId', how='outer') # outer join buyu clientId-n davhtsaliig arilgasan
df_ou
# Out:
#       id  clientId firstName lastName loanStatus_x  loanAmount_x  issueDate_x  \
# 0    1.0    115380     Suren    Itgel         norm    14000000.0       2015.0
# 1    2.0    197540    Chimeg   Baldan         norm    12000000.0       2016.0
# 2    3.0    127843     Gerel     Tsog          bad    14000000.0       2017.0
# 3    4.0    174455   Kherlen     Sukh         ovrd    10000000.0       2015.0
# 4    5.0    104349    Badral  Damchaa         doub    18000000.0       2019.0
# 5    6.0    156346    Dondog    Uuree          bad    16000000.0       2020.0
# 6    7.0    162767      Dash   Byamba         ovrd    13000000.0       2021.0
# 7    8.0    139840       Bat    Bayar         norm    17000000.0       2018.0
# 8    9.0    159625     Saran  Tuvshin          bad    10000000.0       2019.0
# 9   10.0    185473     Naran  Saikhan         subs    13000000.0       2018.0
# 10   NaN    159789       NaN      NaN          NaN           NaN          NaN
# ...

# %%
df_le = pd.merge(df_ind, df_corp, on='clientId', how='left') #ind zeeltei humuus corporate zeeld bga esehiig harna
df_le
# Out:
#    id  clientId firstName lastName loanStatus_x  loanAmount_x  issueDate_x  \
# 0   1    115380     Suren    Itgel         norm      14000000         2015
# 1   2    197540    Chimeg   Baldan         norm      12000000         2016
# 2   3    127843     Gerel     Tsog          bad      14000000         2017
# 3   4    174455   Kherlen     Sukh         ovrd      10000000         2015
# 4   5    104349    Badral  Damchaa         doub      18000000         2019
# 5   6    156346    Dondog    Uuree          bad      16000000         2020
# 6   7    162767      Dash   Byamba         ovrd      13000000         2021
# 7   8    139840       Bat    Bayar         norm      17000000         2018
# 8   9    159625     Saran  Tuvshin          bad      10000000         2019
# 9  10    185473     Naran  Saikhan         subs      13000000         2018
#
#    loanAmount_y  issueDate_y loanStatus_y
# 0    62000000.0       2015.0          bad
# 1           NaN          NaN          NaN
# ...

# %%
df_ri = pd.merge(df_ind, df_corp, on='clientId', how='right') # right join buyu corp zeeltei humuus ind zeeltei esehiig harna
df_ri
# Out:
#      id  clientId firstName lastName loanStatus_x  loanAmount_x  issueDate_x  \
# 0   1.0    115380     Suren    Itgel         norm    14000000.0       2015.0
# 1   3.0    127843     Gerel     Tsog          bad    14000000.0       2017.0
# 2   5.0    104349    Badral  Damchaa         doub    18000000.0       2019.0
# 3   6.0    156346    Dondog    Uuree          bad    16000000.0       2020.0
# 4   7.0    162767      Dash   Byamba         ovrd    13000000.0       2021.0
# 5   9.0    159625     Saran  Tuvshin          bad    10000000.0       2019.0
# 6  10.0    185473     Naran  Saikhan         subs    13000000.0       2018.0
# 7   NaN    159789       NaN      NaN          NaN           NaN          NaN
# 8   NaN    185121       NaN      NaN          NaN           NaN          NaN
#
#    loanAmount_y  issueDate_y loanStatus_y
# 0      62000000         2015          bad
# 1      74000000         2017         doub
# 2      72000000         2019         ovrd
# ...

# %%
df_corp.rename(columns={'clientId': 'userId'}, inplace = True) #corp-n client ID-g userId-r soliv
df_corp
# Out:
#    userId  loanAmount  issueDate loanStatus
# 0  115380    62000000       2015        bad
# 1  127843    74000000       2017       doub
# 2  104349    72000000       2019       ovrd
# 3  156346    79000000       2020       subs
# 4  162767    59000000       2021       norm
# 5  159625    64000000       2019       doub
# 6  185473    68000000       2018        bad
# 7  159789    74000000       2017       norm
# 8  185121    63000000       2019        bad

# %%
pd.merge(df_ind, df_corp, left_on = 'clientId', right_on = 'userId', 
         how ='left', suffixes = ("_ind", "_corp"))
# Out:
#    id  clientId firstName lastName loanStatus_ind  loanAmount_ind  \
# 0   1    115380     Suren    Itgel           norm        14000000
# 1   2    197540    Chimeg   Baldan           norm        12000000
# 2   3    127843     Gerel     Tsog            bad        14000000
# 3   4    174455   Kherlen     Sukh           ovrd        10000000
# 4   5    104349    Badral  Damchaa           doub        18000000
# 5   6    156346    Dondog    Uuree            bad        16000000
# 6   7    162767      Dash   Byamba           ovrd        13000000
# 7   8    139840       Bat    Bayar           norm        17000000
# 8   9    159625     Saran  Tuvshin            bad        10000000
# 9  10    185473     Naran  Saikhan           subs        13000000
#
#    issueDate_ind    userId  loanAmount_corp  issueDate_corp loanStatus_corp
# 0           2015  115380.0       62000000.0          2015.0             bad
# 1           2016       NaN              NaN             NaN             NaN
# ...
